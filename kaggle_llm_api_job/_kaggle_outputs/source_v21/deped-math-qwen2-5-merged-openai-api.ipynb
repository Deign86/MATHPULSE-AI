# %% [markdown]
# # Kaggle API Server Runner
#
# This notebook runs the persistent OpenAI-compatible server script.

# %%
import os

os.environ.setdefault('PYTHONUNBUFFERED', '1')

from serve_kaggle_llm_api import main

main()
